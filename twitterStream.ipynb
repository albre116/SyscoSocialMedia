# %%
###get profile page
import sys
import os
import importlib
sys.path.insert(0,"twitterpackage/Chap02_03")

# %%
###lets get all sysco mutual friends
# !python twitterpackage/Chap02_03/twitter_mutual_friend_followers.py Sysco
# Out:
# Sysco has 283 mutual friends
# Getting Followers for SyscoKnox which is 1 of 283
# Directory users/SyscoKnox already exists moving to next
# Getting Followers for trycakenow which is 2 of 283
# Directory users/trycakenow already exists moving to next
# Getting Followers for SyscoLABSSL which is 3 of 283
# Directory users/SyscoLABSSL already exists moving to next
# Getting Followers for columbiadining which is 4 of 283
# Directory users/columbiadining already exists moving to next
# Getting Followers for warriorlounge which is 5 of 283
# Directory users/warriorlounge already exists moving to next
# Getting Followers for chefmajor72 which is 6 of 283
# Directory users/chefmajor72 already exists moving to next
# Getting Followers for SyscoKelowna which is 7 of 283
# Directory users/SyscoKelowna already exists moving to next
# Getting Followers for factory_pastry which is 8 of 283
# Directory users/factory_pastry already exists moving to next
# Getting Followers for boggsdj which is 9 of 283
# Directory users/boggsdj already exists moving to next
# Getting Followers for LibertyKitchen which is 10 of 283
# Directory users/LibertyKitchen already exists moving to next
# Getting Followers for SyscoBoston which is 11 of 283
# Directory users/SyscoBoston already exists moving to next
# Getting Followers for AmyJoyDonutsInc which is 12 of 283
# Directory users/AmyJoyDonutsInc already exists moving to next
# Getting Followers for cclfruit which is 13 of 283
# Directory users/cclfruit already exists moving to next
# Getting Followers for PearBureau which is 14 of 283
# Directory users/PearBureau already exists moving to next
# Getting Followers for USApears which is 15 of 283
# Directory users/USApears already exists moving to next
# Getting Followers for htpllc which is 16 of 283
# Directory users/htpllc already exists moving to next
# Getting Followers for Sun_Maid which is 17 of 283
# Directory users/Sun_Maid already exists moving to next
# Getting Followers for gracecunning which is 18 of 283
# Directory users/gracecunning already exists moving to next
# Getting Followers for chefjustinHGC which is 19 of 283
# Directory users/chefjustinHGC already exists moving to next
# Getting Followers for CaposRestaurant which is 20 of 283
# Directory users/CaposRestaurant already exists moving to next
# Getting Followers for TeamFNV which is 21 of 283
# Directory users/TeamFNV already exists moving to next
# Getting Followers for JellCraft which is 22 of 283
# Directory users/JellCraft already exists moving to next
# Getting Followers for matt_c_garrett which is 23 of 283
# Directory users/matt_c_garrett already exists moving to next
# Getting Followers for Risoux2 which is 24 of 283
# Directory users/Risoux2 already exists moving to next
# Getting Followers for HouSuperBowl which is 25 of 283
# Directory users/HouSuperBowl already exists moving to next
# Getting Followers for timmingto which is 26 of 283
# Directory users/timmingto already exists moving to next
# Getting Followers for SyscoCTX which is 27 of 283
# Directory users/SyscoCTX already exists moving to next
# Getting Followers for ArcticFisheries which is 28 of 283
# Directory users/ArcticFisheries already exists moving to next
# Getting Followers for MTBeefCouncil which is 29 of 283
# Directory users/MTBeefCouncil already exists moving to next
# Getting Followers for StateStreetPubs which is 30 of 283
# Directory users/StateStreetPubs already exists moving to next
# Getting Followers for LasMargaritasBC which is 31 of 283
# Directory users/LasMargaritasBC already exists moving to next
# Getting Followers for spag_factory which is 32 of 283
# Directory users/spag_factory already exists moving to next
# Getting Followers for MormonStepmom which is 33 of 283
# Directory users/MormonStepmom already exists moving to next
# Getting Followers for ccandasmile which is 34 of 283
# Directory users/ccandasmile already exists moving to next
# Getting Followers for FreshPointInc which is 35 of 283
# Directory users/FreshPointInc already exists moving to next
# Getting Followers for WyseCarts which is 36 of 283
# Directory users/WyseCarts already exists moving to next
# Getting Followers for americaneatsgy which is 37 of 283
# Directory users/americaneatsgy already exists moving to next
# Getting Followers for ingallinas which is 38 of 283
# Directory users/ingallinas already exists moving to next
# Getting Followers for BakerandcoNY which is 39 of 283
# Directory users/BakerandcoNY already exists moving to next
# Getting Followers for CornerstoneMain which is 40 of 283
# Directory users/CornerstoneMain already exists moving to next
# Getting Followers for Cambro1 which is 41 of 283
# Directory users/Cambro1 already exists moving to next
# Getting Followers for RonRuggless which is 42 of 283
# Directory users/RonRuggless already exists moving to next
# Getting Followers for 2guyspiesBOP which is 43 of 283
# Directory users/2guyspiesBOP already exists moving to next
# Getting Followers for KatColeATL which is 44 of 283
# Directory users/KatColeATL already exists moving to next
# Getting Followers for HattieHillWFF which is 45 of 283
# Directory users/HattieHillWFF already exists moving to next
# Getting Followers for PizzaExpo which is 46 of 283
# Directory users/PizzaExpo already exists moving to next
# Getting Followers for mainedan which is 47 of 283
# Directory users/mainedan already exists moving to next
# Getting Followers for thedailymeal which is 48 of 283
# Directory users/thedailymeal already exists moving to next
# Getting Followers for SoulCatCuisine which is 49 of 283
# Directory users/SoulCatCuisine already exists moving to next
# Getting Followers for ALStateParks which is 50 of 283
# Directory users/ALStateParks already exists moving to next
# Getting Followers for TSmoothieCafe which is 51 of 283
# Directory users/TSmoothieCafe already exists moving to next
# Getting Followers for TDsBBQ_Wgtn which is 52 of 283
# Directory users/TDsBBQ_Wgtn already exists moving to next
# Getting Followers for LaGarzaBurgers which is 53 of 283
# Directory users/LaGarzaBurgers already exists moving to next
# Getting Followers for VegFreshFarms which is 54 of 283
# Directory users/VegFreshFarms already exists moving to next
# Getting Followers for FoodBank4NYC which is 55 of 283
# Directory users/FoodBank4NYC already exists moving to next
# Getting Followers for CompassTavernWo which is 56 of 283
# Directory users/CompassTavernWo already exists moving to next
# Getting Followers for Cowrestaurant1 which is 57 of 283
# Directory users/Cowrestaurant1 already exists moving to next
# Getting Followers for BerniesBurgers which is 58 of 283
# Directory users/BerniesBurgers already exists moving to next
# Getting Followers for 4LLD4Y which is 59 of 283
# Directory users/4LLD4Y already exists moving to next
# Getting Followers for Willydome which is 60 of 283
# Directory users/Willydome already exists moving to next
# Getting Followers for lacookiecon which is 61 of 283
# Directory users/lacookiecon already exists moving to next
# Getting Followers for Pitasbites which is 62 of 283
# Directory users/Pitasbites already exists moving to next
# Getting Followers for PBConventionCtr which is 63 of 283
# Directory users/PBConventionCtr already exists moving to next
# Getting Followers for RestAssocNS which is 64 of 283
# Directory users/RestAssocNS already exists moving to next
# Getting Followers for wowdessert which is 65 of 283
# Directory users/wowdessert already exists moving to next
# Getting Followers for MLStadium which is 66 of 283
# Directory users/MLStadium already exists moving to next
# Getting Followers for johnsoulesfoods which is 67 of 283
# Directory users/johnsoulesfoods already exists moving to next
# Getting Followers for The_BigBiscuit which is 68 of 283
# Directory users/The_BigBiscuit already exists moving to next
# Getting Followers for CrtHerefordBeef which is 69 of 283
# Directory users/CrtHerefordBeef already exists moving to next
# Getting Followers for HGIOXNARD which is 70 of 283
# Directory users/HGIOXNARD already exists moving to next
# Getting Followers for mysyerie which is 71 of 283
# Directory users/mysyerie already exists moving to next
# Getting Followers for TheGoodBag which is 72 of 283
# Directory users/TheGoodBag already exists moving to next
# Getting Followers for NickCiafre which is 73 of 283
# Failed to run the followers command on that user, Skipping...
# Failed to run the friends command on that user, Skipping...
# Getting Followers for taproduce which is 74 of 283
# Getting Followers for Tyson4Chefs which is 75 of 283
# Getting Followers for publickitchensp which is 76 of 283
# Getting Followers for HFSoulfood1 which is 77 of 283
# Getting Followers for ChefKellz which is 78 of 283
# Getting Followers for MoonRoosterHTX which is 79 of 283
# Getting Followers for CoffeeAmbulance which is 80 of 283
# Getting Followers for TheLoneStarGuys which is 81 of 283
# Getting Followers for PoBoy_Express which is 82 of 283
# Getting Followers for PockettoMe which is 83 of 283
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 15
# Getting Followers for FreshBlendz which is 84 of 283
# Getting Followers for SarahE_Scully which is 85 of 283
# Getting Followers for CurbsideSliderz which is 86 of 283
# Getting Followers for LoHarrison6 which is 87 of 283
# Getting Followers for tasteofmex which is 88 of 283
# Getting Followers for Bageladies which is 89 of 283
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 15
# Getting Followers for ChefsRuleBBQPit which is 90 of 283
# Getting Followers for GreenNtheGrain which is 91 of 283
# Getting Followers for ghostpepperz1 which is 92 of 283
# Getting Followers for vmarketsfsu which is 93 of 283
# Getting Followers for latinfoodfest which is 94 of 283
# Getting Followers for MushuGrill which is 95 of 283
# Getting Followers for Gillis_Farms which is 96 of 283
# Getting Followers for Chef_DirtyD which is 97 of 283
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 15
# Getting Followers for voght_jeff which is 98 of 283
# Getting Followers for RD_Conference which is 99 of 283
# Getting Followers for CapersTweets which is 100 of 283
# Getting Followers for FB101com which is 101 of 283
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 15
# Getting Followers for steveGOgreen which is 102 of 283
# Getting Followers for PKCosmicCastle which is 103 of 283
# Getting Followers for ChefMcLay which is 104 of 283
# Getting Followers for Foodiechats which is 105 of 283
# Getting Followers for IFBTA which is 106 of 283
# Getting Followers for foodoko which is 107 of 283
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 15
# Getting Followers for LinZMcNeil which is 108 of 283
# Getting Followers for tnuctkmckay which is 109 of 283
# Getting Followers for clee131 which is 110 of 283
# Getting Followers for 4CountryDelight which is 111 of 283
# Getting Followers for okanaganbreeze which is 112 of 283
# Getting Followers for CarolinaKitchen which is 113 of 283
# Getting Followers for BenoitsBakery which is 114 of 283
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 15
# Getting Followers for TheMasonDixon1 which is 115 of 283
# Getting Followers for bustinicatering which is 116 of 283
# Getting Followers for KymaRestaurant which is 117 of 283
# Getting Followers for tuttopizzapasta which is 118 of 283
# Getting Followers for saveroomforpie which is 119 of 283
# Getting Followers for BurgooBistro which is 120 of 283
# Getting Followers for CHARofjackson which is 121 of 283
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 15
# Getting Followers for NormandsBistro which is 122 of 283
# Getting Followers for RestStartupGrow which is 123 of 283
# Getting Followers for QuickSandwiches which is 124 of 283
# Getting Followers for ChangThaiCafe which is 125 of 283
# Getting Followers for ILuvSweetSpot which is 126 of 283
# Getting Followers for TexasEduKids which is 127 of 283
# Getting Followers for BortonFruit which is 128 of 283
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1
# Checked API and limit is at 1
# Sleeping for 30 seconds to check rate limit which is at 1

# %%
###lets try the stream thing
# !python twitterpackage/Chap02_03/twitter_streaming.py \#farmtotable \#maga
# Out:
# ^C
# Exception ignored in: <module 'threading' from '/usr/lib/python3.5/threading.py'>
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 1288, in _shutdown
#     t.join()
#   File "/usr/lib/python3.5/threading.py", line 1054, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.5/threading.py", line 1070, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
